# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
# install dependencies
# !pip -q install ../python
# Out:
# menpo 0.8.1 has requirement matplotlib<2.0,>=1.4, but you'll have matplotlib 3.0.2 which is incompatible.
# menpo 0.8.1 has requirement pillow<5.0,>=3.0, but you'll have pillow 5.4.0 which is incompatible.
# menpo 0.8.1 has requirement scipy<1.0,>=0.16, but you'll have scipy 1.2.0 which is incompatible.
# fastai 1.0.42 has requirement torch>=1.0.0, but you'll have torch 0.4.0 which is incompatible.
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# check GPU state
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
# TODO: Comment out if you want to see random actions 
# env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
# states = env_info.vector_observations                  # get the current state (for each agent)
# scores = np.zeros(num_agents)                          # initialize the score (for each agent)
# while True:
#     actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#     actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#     env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#     next_states = env_info.vector_observations         # get next state (for each agent)
#     rewards = env_info.rewards                         # get reward (for each agent)
#     dones = env_info.local_done                        # see if episode finished
#     scores += env_info.rewards                         # update the score (for each agent)
#     states = next_states                               # roll over states to next time step
#     if np.any(dones):                                  # exit loop if episode finished
#         break
# print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
# create agent
from ddpg_agent import Agent
agent = Agent(state_size=state_size, action_size=action_size, random_seed=1)

# %%
from collections import deque
import time, torch

# train with ddpg
def ddpg(n_episodes=1000, max_t=2000, solved_score=30.0, average_score_window=100,
         actor_path='actor.pth', critic_path='critic.pth'):
    """Deep Deterministic Policy Gradient (DDPG)
    
    Params
    ======
        n_episodes (int)      : maximum number of training episodes
        max_t (int)           : maximum number of timesteps per episode
        average_score_window (int): size of most recent scores
        solved_score (float)  : min avg score over consecutive episodes
        actor_path (str)      : directory to store actor network weights
        critic_path (str)     : directory to store critic network weights

    """
    mean_scores = []                               # list of mean scores from each episode
    min_scores = []                                # list of lowest scores from each episode
    max_scores = []                                # list of highest scores from each episode
    best_score = -np.inf
    scores_window = deque(maxlen=average_score_window)             # mean scores from most recent episodes
    moving_avgs = []                               # list of moving averages
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name] # reset environment
        states = env_info.vector_observations                   # get current state for each agent      
        scores = np.zeros(num_agents)                           # initialize score for each agent
        agent.reset()
        start_time = time.time()
        for t in range(max_t):
            actions = agent.act(states, add_noise=True)         # select an action
            env_info = env.step(actions)[brain_name]            # send actions to environment
            next_states = env_info.vector_observations          # get next state
            rewards = env_info.rewards                          # get reward
            dones = env_info.local_done                         # see if episode has finished
            # save experience to replay buffer, perform learning step at defined interval
            for state, action, reward, next_state, done in zip(states, actions, rewards, next_states, dones):
                agent.step(state, action, reward, next_state, done, t)             
            states = next_states
            scores += rewards
            
            if t % 100 == 0:
                print('\rEpisode {} Trial {}'.format(i_episode, t))
            
            if np.any(dones):                                   # exit loop when episode ends
                break

        duration = time.time() - start_time
        min_scores.append(np.min(scores))             # save lowest score for a single agent
        max_scores.append(np.max(scores))             # save highest score for a single agent        
        mean_scores.append(np.mean(scores))           # save mean score for the episode
        scores_window.append(mean_scores[-1])         # save mean score to window
        moving_avgs.append(np.mean(scores_window))    # save moving average
                
        print('\rEpisode {} ({} sec)  -- \tMin: {:.1f}\tMax: {:.1f}\tMean: {:.1f}\tMov. Avg: {:.1f}'.format(\
              i_episode, round(duration), min_scores[-1], max_scores[-1], mean_scores[-1], moving_avgs[-1]))
        
        if mean_scores[-1] > best_score:
            torch.save(agent.actor_local.state_dict(), actor_path)
            torch.save(agent.critic_local.state_dict(), critic_path)
                  
        if moving_avgs[-1] >= solved_score and i_episode >= average_score_window:
            print('\nEnvironment SOLVED in {} episodes!\tMoving Average ={:.1f} over last {} episodes'.format(\
                                    i_episode-average_score_window, moving_avgs[-1], average_score_window))            
            torch.save(agent.actor_local.state_dict(), actor_path)
            torch.save(agent.critic_local.state_dict(), critic_path)
            break
            
    return mean_scores, moving_avgs

# %%
# train the agent
scores, avgs = ddpg()
# Out:
# Episode 1 Trial 0
# Episode 1 Trial 100
# Episode 1 Trial 200
# Episode 1 Trial 300
# Episode 1 Trial 400
# Episode 1 Trial 500
# Episode 1 Trial 600
# Episode 1 Trial 700
# Episode 1 Trial 800
# Episode 1 Trial 900
# Episode 1 Trial 1000
# Episode 1 (90 sec)  -- 	Min: 0.0	Max: 1.6	Mean: 0.6	Mov. Avg: 0.6
# Episode 2 Trial 0
# Episode 2 Trial 100
# Episode 2 Trial 200
# Episode 2 Trial 300
# Episode 2 Trial 400
# Episode 2 Trial 500
# Episode 2 Trial 600
# Episode 2 Trial 700
# Episode 2 Trial 800
# Episode 2 Trial 900
# Episode 2 Trial 1000
# Episode 2 (93 sec)  -- 	Min: 0.4	Max: 2.2	Mean: 1.1	Mov. Avg: 0.9
# Episode 3 Trial 0
# Episode 3 Trial 100
# Episode 3 Trial 200
# Episode 3 Trial 300
# Episode 3 Trial 400
# Episode 3 Trial 500
# Episode 3 Trial 600
# Episode 3 Trial 700
# Episode 3 Trial 800
# Episode 3 Trial 900
# Episode 3 Trial 1000
# Episode 3 (94 sec)  -- 	Min: 0.5	Max: 4.8	Mean: 1.8	Mov. Avg: 1.2
# Episode 4 Trial 0
# Episode 4 Trial 100
# Episode 4 Trial 200
# Episode 4 Trial 300
# Episode 4 Trial 400
# Episode 4 Trial 500
# Episode 4 Trial 600
# Episode 4 Trial 700
# Episode 4 Trial 800
# Episode 4 Trial 900
# Episode 4 Trial 1000
# Episode 4 (94 sec)  -- 	Min: 1.6	Max: 4.3	Mean: 2.4	Mov. Avg: 1.5
# Episode 5 Trial 0
# Episode 5 Trial 100
# Episode 5 Trial 200
# Episode 5 Trial 300
# Episode 5 Trial 400
# Episode 5 Trial 500
# Episode 5 Trial 600
# Episode 5 Trial 700
# Episode 5 Trial 800
# Episode 5 Trial 900
# Episode 5 Trial 1000
# Episode 5 (95 sec)  -- 	Min: 1.2	Max: 4.7	Mean: 2.3	Mov. Avg: 1.7
# Episode 6 Trial 0
# Episode 6 Trial 100
# Episode 6 Trial 200
# Episode 6 Trial 300
# Episode 6 Trial 400
# Episode 6 Trial 500
# Episode 6 Trial 600
# Episode 6 Trial 700
# Episode 6 Trial 800
# Episode 6 Trial 900
# Episode 6 Trial 1000
# Episode 6 (96 sec)  -- 	Min: 1.0	Max: 5.3	Mean: 2.7	Mov. Avg: 1.8
# Episode 7 Trial 0
# Episode 7 Trial 100
# Episode 7 Trial 200
# Episode 7 Trial 300
# Episode 7 Trial 400
# Episode 7 Trial 500
# Episode 7 Trial 600
# Episode 7 Trial 700
# Episode 7 Trial 800
# Episode 7 Trial 900
# Episode 7 Trial 1000
# Episode 7 (97 sec)  -- 	Min: 0.0	Max: 5.8	Mean: 2.5	Mov. Avg: 1.9
# Episode 8 Trial 0
# Episode 8 Trial 100
# Episode 8 Trial 200
# Episode 8 Trial 300
# Episode 8 Trial 400
# Episode 8 Trial 500
# Episode 8 Trial 600
# Episode 8 Trial 700
# Episode 8 Trial 800
# Episode 8 Trial 900
# Episode 8 Trial 1000
# Episode 8 (98 sec)  -- 	Min: 0.6	Max: 5.7	Mean: 3.0	Mov. Avg: 2.1
# Episode 9 Trial 0
# Episode 9 Trial 100
# Episode 9 Trial 200
# Episode 9 Trial 300
# Episode 9 Trial 400
# Episode 9 Trial 500
# Episode 9 Trial 600
# Episode 9 Trial 700
# Episode 9 Trial 800
# Episode 9 Trial 900
# Episode 9 Trial 1000
# Episode 9 (99 sec)  -- 	Min: 1.6	Max: 4.1	Mean: 2.9	Mov. Avg: 2.2
# Episode 10 Trial 0
# Episode 10 Trial 100
# Episode 10 Trial 200
# Episode 10 Trial 300
# Episode 10 Trial 400
# Episode 10 Trial 500
# Episode 10 Trial 600
# Episode 10 Trial 700
# Episode 10 Trial 800
# Episode 10 Trial 900
# Episode 10 Trial 1000
# Episode 10 (100 sec)  -- 	Min: 1.1	Max: 9.6	Mean: 3.8	Mov. Avg: 2.3
# Episode 11 Trial 0
# Episode 11 Trial 100
# Episode 11 Trial 200
# Episode 11 Trial 300
# Episode 11 Trial 400
# Episode 11 Trial 500
# Episode 11 Trial 600
# Episode 11 Trial 700
# Episode 11 Trial 800
# Episode 11 Trial 900
# Episode 11 Trial 1000
# Episode 11 (101 sec)  -- 	Min: 1.5	Max: 6.0	Mean: 4.3	Mov. Avg: 2.5
# Episode 12 Trial 0
# Episode 12 Trial 100
# Episode 12 Trial 200
# Episode 12 Trial 300
# Episode 12 Trial 400
# Episode 12 Trial 500
# Episode 12 Trial 600
# Episode 12 Trial 700
# Episode 12 Trial 800
# Episode 12 Trial 900
# Episode 12 Trial 1000
# Episode 12 (102 sec)  -- 	Min: 2.3	Max: 8.7	Mean: 4.6	Mov. Avg: 2.7
# Episode 13 Trial 0
# Episode 13 Trial 100
# Episode 13 Trial 200
# Episode 13 Trial 300
# Episode 13 Trial 400
# Episode 13 Trial 500
# Episode 13 Trial 600
# Episode 13 Trial 700
# Episode 13 Trial 800
# Episode 13 Trial 900
# Episode 13 Trial 1000
# Episode 13 (104 sec)  -- 	Min: 1.4	Max: 7.7	Mean: 4.3	Mov. Avg: 2.8
# Episode 14 Trial 0
# Episode 14 Trial 100
# Episode 14 Trial 200
# Episode 14 Trial 300
# Episode 14 Trial 400
# Episode 14 Trial 500
# Episode 14 Trial 600
# Episode 14 Trial 700
# Episode 14 Trial 800
# Episode 14 Trial 900
# Episode 14 Trial 1000
# Episode 14 (106 sec)  -- 	Min: 2.4	Max: 10.8	Mean: 5.4	Mov. Avg: 3.0
# Episode 15 Trial 0
# Episode 15 Trial 100
# Episode 15 Trial 200
# Episode 15 Trial 300
# Episode 15 Trial 400
# Episode 15 Trial 500
# Episode 15 Trial 600
# Episode 15 Trial 700
# Episode 15 Trial 800
# Episode 15 Trial 900
# Episode 15 Trial 1000
# Episode 15 (108 sec)  -- 	Min: 3.8	Max: 9.4	Mean: 6.5	Mov. Avg: 3.2
# Episode 16 Trial 0
# Episode 16 Trial 100
# Episode 16 Trial 200
# Episode 16 Trial 300
# Episode 16 Trial 400
# Episode 16 Trial 500
# Episode 16 Trial 600
# Episode 16 Trial 700
# Episode 16 Trial 800
# Episode 16 Trial 900
# Episode 16 Trial 1000
# Episode 16 (110 sec)  -- 	Min: 3.8	Max: 10.3	Mean: 6.6	Mov. Avg: 3.4
# Episode 17 Trial 0
# Episode 17 Trial 100
# Episode 17 Trial 200
# Episode 17 Trial 300
# Episode 17 Trial 400
# Episode 17 Trial 500
# Episode 17 Trial 600
# Episode 17 Trial 700
# Episode 17 Trial 800
# Episode 17 Trial 900
# Episode 17 Trial 1000
# Episode 17 (111 sec)  -- 	Min: 4.7	Max: 11.6	Mean: 7.2	Mov. Avg: 3.7
# Episode 18 Trial 0
# Episode 18 Trial 100
# Episode 18 Trial 200
# Episode 18 Trial 300
# Episode 18 Trial 400
# Episode 18 Trial 500
# Episode 18 Trial 600
# Episode 18 Trial 700
# Episode 18 Trial 800
# Episode 18 Trial 900
# Episode 18 Trial 1000
# Episode 18 (113 sec)  -- 	Min: 3.3	Max: 8.8	Mean: 6.2	Mov. Avg: 3.8
# Episode 19 Trial 0
# Episode 19 Trial 100
# Episode 19 Trial 200
# Episode 19 Trial 300
# Episode 19 Trial 400
# Episode 19 Trial 500
# Episode 19 Trial 600
# Episode 19 Trial 700
# Episode 19 Trial 800
# Episode 19 Trial 900
# Episode 19 Trial 1000
# Episode 19 (116 sec)  -- 	Min: 3.7	Max: 11.4	Mean: 6.6	Mov. Avg: 3.9
# Episode 20 Trial 0
# Episode 20 Trial 100
# Episode 20 Trial 200
# Episode 20 Trial 300
# Episode 20 Trial 400
# Episode 20 Trial 500
# Episode 20 Trial 600
# Episode 20 Trial 700
# Episode 20 Trial 800
# Episode 20 Trial 900
# Episode 20 Trial 1000
# Episode 20 (118 sec)  -- 	Min: 4.7	Max: 10.0	Mean: 6.9	Mov. Avg: 4.1
# Episode 21 Trial 0
# Episode 21 Trial 100
# Episode 21 Trial 200
# Episode 21 Trial 300
# Episode 21 Trial 400
# Episode 21 Trial 500
# Episode 21 Trial 600
# Episode 21 Trial 700
# Episode 21 Trial 800
# Episode 21 Trial 900
# Episode 21 Trial 1000
# Episode 21 (120 sec)  -- 	Min: 3.3	Max: 14.3	Mean: 9.1	Mov. Avg: 4.3
# Episode 22 Trial 0
# Episode 22 Trial 100
# Episode 22 Trial 200
# Episode 22 Trial 300
# Episode 22 Trial 400
# Episode 22 Trial 500
# Episode 22 Trial 600
# Episode 22 Trial 700
# Episode 22 Trial 800
# Episode 22 Trial 900
# Episode 22 Trial 1000
# Episode 22 (122 sec)  -- 	Min: 4.9	Max: 11.8	Mean: 8.9	Mov. Avg: 4.5
# Episode 23 Trial 0
# Episode 23 Trial 100
# Episode 23 Trial 200
# Episode 23 Trial 300
# Episode 23 Trial 400
# Episode 23 Trial 500
# Episode 23 Trial 600
# Episode 23 Trial 700
# Episode 23 Trial 800
# Episode 23 Trial 900
# Episode 23 Trial 1000
# Episode 23 (124 sec)  -- 	Min: 4.8	Max: 14.6	Mean: 9.9	Mov. Avg: 4.8
# Episode 24 Trial 0
# Episode 24 Trial 100
# Episode 24 Trial 200
# Episode 24 Trial 300
# Episode 24 Trial 400
# Episode 24 Trial 500
# Episode 24 Trial 600
# Episode 24 Trial 700
# Episode 24 Trial 800
# Episode 24 Trial 900
# Episode 24 Trial 1000
# Episode 24 (126 sec)  -- 	Min: 4.4	Max: 14.8	Mean: 9.7	Mov. Avg: 5.0
# Episode 25 Trial 0
# Episode 25 Trial 100
# Episode 25 Trial 200
# Episode 25 Trial 300
# Episode 25 Trial 400
# Episode 25 Trial 500
# Episode 25 Trial 600
# Episode 25 Trial 700
# Episode 25 Trial 800
# Episode 25 Trial 900
# Episode 25 Trial 1000
# Episode 25 (129 sec)  -- 	Min: 4.7	Max: 19.2	Mean: 11.2	Mov. Avg: 5.2
# Episode 26 Trial 0
# Episode 26 Trial 100
# Episode 26 Trial 200
# Episode 26 Trial 300
# Episode 26 Trial 400
# Episode 26 Trial 500
# Episode 26 Trial 600
# Episode 26 Trial 700
# Episode 26 Trial 800
# Episode 26 Trial 900
# Episode 26 Trial 1000
# Episode 26 (130 sec)  -- 	Min: 4.3	Max: 20.7	Mean: 10.8	Mov. Avg: 5.4
# Episode 27 Trial 0
# Episode 27 Trial 100
# Episode 27 Trial 200
# Episode 27 Trial 300
# Episode 27 Trial 400
# Episode 27 Trial 500
# Episode 27 Trial 600
# Episode 27 Trial 700
# Episode 27 Trial 800
# Episode 27 Trial 900
# Episode 27 Trial 1000
# Episode 27 (133 sec)  -- 	Min: 5.2	Max: 15.6	Mean: 11.1	Mov. Avg: 5.7
# Episode 28 Trial 0
# Episode 28 Trial 100
# Episode 28 Trial 200
# Episode 28 Trial 300
# Episode 28 Trial 400
# Episode 28 Trial 500
# Episode 28 Trial 600
# Episode 28 Trial 700
# Episode 28 Trial 800
# Episode 28 Trial 900
# Episode 28 Trial 1000
# Episode 28 (135 sec)  -- 	Min: 4.9	Max: 16.7	Mean: 11.6	Mov. Avg: 5.9
# Episode 29 Trial 0
# Episode 29 Trial 100
# Episode 29 Trial 200
# Episode 29 Trial 300
# Episode 29 Trial 400
# Episode 29 Trial 500
# Episode 29 Trial 600
# Episode 29 Trial 700
# Episode 29 Trial 800
# Episode 29 Trial 900
# Episode 29 Trial 1000
# Episode 29 (138 sec)  -- 	Min: 7.1	Max: 19.8	Mean: 12.9	Mov. Avg: 6.1
# Episode 30 Trial 0
# Episode 30 Trial 100
# Episode 30 Trial 200
# Episode 30 Trial 300
# Episode 30 Trial 400
# Episode 30 Trial 500
# Episode 30 Trial 600
# Episode 30 Trial 700
# Episode 30 Trial 800
# Episode 30 Trial 900
# Episode 30 Trial 1000
# Episode 30 (140 sec)  -- 	Min: 5.9	Max: 21.6	Mean: 12.0	Mov. Avg: 6.3
# Episode 31 Trial 0
# Episode 31 Trial 100
# Episode 31 Trial 200
# Episode 31 Trial 300
# Episode 31 Trial 400
# Episode 31 Trial 500
# Episode 31 Trial 600
# Episode 31 Trial 700
# Episode 31 Trial 800
# Episode 31 Trial 900
# Episode 31 Trial 1000
# Episode 31 (141 sec)  -- 	Min: 5.3	Max: 21.5	Mean: 12.5	Mov. Avg: 6.5
# Episode 32 Trial 0
# Episode 32 Trial 100
# Episode 32 Trial 200
# Episode 32 Trial 300
# Episode 32 Trial 400
# Episode 32 Trial 500
# Episode 32 Trial 600
# Episode 32 Trial 700
# Episode 32 Trial 800
# Episode 32 Trial 900
# Episode 32 Trial 1000
# Episode 32 (144 sec)  -- 	Min: 7.9	Max: 22.9	Mean: 15.8	Mov. Avg: 6.8
# Episode 33 Trial 0
# Episode 33 Trial 100
# Episode 33 Trial 200
# Episode 33 Trial 300
# Episode 33 Trial 400
# Episode 33 Trial 500
# Episode 33 Trial 600
# Episode 33 Trial 700
# Episode 33 Trial 800
# Episode 33 Trial 900
# Episode 33 Trial 1000
# Episode 33 (146 sec)  -- 	Min: 7.5	Max: 22.6	Mean: 17.4	Mov. Avg: 7.1
# Episode 34 Trial 0
# Episode 34 Trial 100
# Episode 34 Trial 200
# Episode 34 Trial 300
# Episode 34 Trial 400
# Episode 34 Trial 500
# Episode 34 Trial 600
# Episode 34 Trial 700
# Episode 34 Trial 800
# Episode 34 Trial 900
# Episode 34 Trial 1000
# Episode 34 (148 sec)  -- 	Min: 5.2	Max: 26.8	Mean: 14.9	Mov. Avg: 7.3
# Episode 35 Trial 0
# Episode 35 Trial 100
# Episode 35 Trial 200
# Episode 35 Trial 300
# Episode 35 Trial 400
# Episode 35 Trial 500
# Episode 35 Trial 600
# Episode 35 Trial 700
# Episode 35 Trial 800
# Episode 35 Trial 900
# Episode 35 Trial 1000
# Episode 35 (150 sec)  -- 	Min: 8.0	Max: 23.4	Mean: 15.7	Mov. Avg: 7.6
# Episode 36 Trial 0
# Episode 36 Trial 100
# Episode 36 Trial 200
# Episode 36 Trial 300
# Episode 36 Trial 400
# Episode 36 Trial 500
# Episode 36 Trial 600
# Episode 36 Trial 700
# Episode 36 Trial 800
# Episode 36 Trial 900
# Episode 36 Trial 1000
# Episode 36 (152 sec)  -- 	Min: 4.9	Max: 22.4	Mean: 14.7	Mov. Avg: 7.8
# Episode 37 Trial 0
# Episode 37 Trial 100
# Episode 37 Trial 200
# Episode 37 Trial 300
# Episode 37 Trial 400
# Episode 37 Trial 500
# Episode 37 Trial 600
# Episode 37 Trial 700
# Episode 37 Trial 800
# Episode 37 Trial 900
# Episode 37 Trial 1000
# Episode 37 (155 sec)  -- 	Min: 8.7	Max: 26.8	Mean: 17.1	Mov. Avg: 8.0
# Episode 38 Trial 0
# Episode 38 Trial 100
# Episode 38 Trial 200
# Episode 38 Trial 300
# Episode 38 Trial 400
# Episode 38 Trial 500
# Episode 38 Trial 600
# Episode 38 Trial 700
# Episode 38 Trial 800
# Episode 38 Trial 900
# Episode 38 Trial 1000
# Episode 38 (157 sec)  -- 	Min: 8.7	Max: 25.7	Mean: 15.8	Mov. Avg: 8.2
# Episode 39 Trial 0
# Episode 39 Trial 100
# Episode 39 Trial 200
# Episode 39 Trial 300
# Episode 39 Trial 400
# Episode 39 Trial 500
# Episode 39 Trial 600
# Episode 39 Trial 700
# Episode 39 Trial 800
# Episode 39 Trial 900
# Episode 39 Trial 1000
# Episode 39 (160 sec)  -- 	Min: 7.1	Max: 26.4	Mean: 15.6	Mov. Avg: 8.4
# Episode 40 Trial 0
# Episode 40 Trial 100
# Episode 40 Trial 200
# Episode 40 Trial 300
# Episode 40 Trial 400
# Episode 40 Trial 500
# Episode 40 Trial 600
# Episode 40 Trial 700
# Episode 40 Trial 800
# Episode 40 Trial 900
# Episode 40 Trial 1000
# Episode 40 (162 sec)  -- 	Min: 5.1	Max: 24.2	Mean: 16.5	Mov. Avg: 8.6
# Episode 41 Trial 0
# Episode 41 Trial 100
# Episode 41 Trial 200
# Episode 41 Trial 300
# Episode 41 Trial 400
# Episode 41 Trial 500
# Episode 41 Trial 600
# Episode 41 Trial 700
# Episode 41 Trial 800
# Episode 41 Trial 900
# Episode 41 Trial 1000
# Episode 41 (164 sec)  -- 	Min: 8.7	Max: 34.6	Mean: 16.6	Mov. Avg: 8.8
# Episode 42 Trial 0
# Episode 42 Trial 100
# Episode 42 Trial 200
# Episode 42 Trial 300
# Episode 42 Trial 400
# Episode 42 Trial 500
# Episode 42 Trial 600
# Episode 42 Trial 700
# Episode 42 Trial 800
# Episode 42 Trial 900
# Episode 42 Trial 1000
# Episode 42 (167 sec)  -- 	Min: 5.8	Max: 27.8	Mean: 16.5	Mov. Avg: 9.0
# Episode 43 Trial 0
# Episode 43 Trial 100
# Episode 43 Trial 200
# Episode 43 Trial 300
# Episode 43 Trial 400
# Episode 43 Trial 500
# Episode 43 Trial 600
# Episode 43 Trial 700
# Episode 43 Trial 800
# Episode 43 Trial 900
# Episode 43 Trial 1000
# Episode 43 (169 sec)  -- 	Min: 10.8	Max: 32.7	Mean: 20.8	Mov. Avg: 9.3
# Episode 44 Trial 0
# Episode 44 Trial 100
# Episode 44 Trial 200
# Episode 44 Trial 300
# Episode 44 Trial 400
# Episode 44 Trial 500
# Episode 44 Trial 600
# Episode 44 Trial 700
# Episode 44 Trial 800
# Episode 44 Trial 900
# Episode 44 Trial 1000
# Episode 44 (172 sec)  -- 	Min: 8.6	Max: 25.6	Mean: 16.5	Mov. Avg: 9.4
# Episode 45 Trial 0
# Episode 45 Trial 100
# Episode 45 Trial 200
# Episode 45 Trial 300
# Episode 45 Trial 400
# Episode 45 Trial 500
# Episode 45 Trial 600
# Episode 45 Trial 700
# Episode 45 Trial 800
# Episode 45 Trial 900
# Episode 45 Trial 1000
# Episode 45 (174 sec)  -- 	Min: 6.2	Max: 27.2	Mean: 18.5	Mov. Avg: 9.6
# Episode 46 Trial 0
# Episode 46 Trial 100
# Episode 46 Trial 200
# Episode 46 Trial 300
# Episode 46 Trial 400
# Episode 46 Trial 500
# Episode 46 Trial 600
# Episode 46 Trial 700
# Episode 46 Trial 800
# Episode 46 Trial 900
# Episode 46 Trial 1000
# Episode 46 (176 sec)  -- 	Min: 12.9	Max: 27.2	Mean: 19.1	Mov. Avg: 9.8
# Episode 47 Trial 0
# Episode 47 Trial 100
# Episode 47 Trial 200
# Episode 47 Trial 300
# Episode 47 Trial 400
# Episode 47 Trial 500
# Episode 47 Trial 600
# Episode 47 Trial 700
# Episode 47 Trial 800
# Episode 47 Trial 900
# Episode 47 Trial 1000
# Episode 47 (179 sec)  -- 	Min: 13.6	Max: 35.7	Mean: 19.6	Mov. Avg: 10.1
# Episode 48 Trial 0
# Episode 48 Trial 100
# Episode 48 Trial 200
# Episode 48 Trial 300
# Episode 48 Trial 400
# Episode 48 Trial 500
# Episode 48 Trial 600
# Episode 48 Trial 700
# Episode 48 Trial 800
# Episode 48 Trial 900
# Episode 48 Trial 1000
# Episode 48 (181 sec)  -- 	Min: 9.5	Max: 29.5	Mean: 18.6	Mov. Avg: 10.2
# Episode 49 Trial 0
# Episode 49 Trial 100
# Episode 49 Trial 200
# Episode 49 Trial 300
# Episode 49 Trial 400
# Episode 49 Trial 500
# Episode 49 Trial 600
# Episode 49 Trial 700
# Episode 49 Trial 800
# Episode 49 Trial 900
# Episode 49 Trial 1000
# Episode 49 (184 sec)  -- 	Min: 13.4	Max: 26.3	Mean: 18.6	Mov. Avg: 10.4
# Episode 50 Trial 0
# Episode 50 Trial 100
# Episode 50 Trial 200
# Episode 50 Trial 300
# Episode 50 Trial 400
# Episode 50 Trial 500
# Episode 50 Trial 600
# Episode 50 Trial 700
# Episode 50 Trial 800
# Episode 50 Trial 900
# Episode 50 Trial 1000
# Episode 50 (189 sec)  -- 	Min: 11.7	Max: 24.7	Mean: 19.0	Mov. Avg: 10.6
# Episode 51 Trial 0
# Episode 51 Trial 100
# Episode 51 Trial 200
# Episode 51 Trial 300
# Episode 51 Trial 400
# Episode 51 Trial 500
# Episode 51 Trial 600
# Episode 51 Trial 700
# Episode 51 Trial 800
# Episode 51 Trial 900
# Episode 51 Trial 1000
# Episode 51 (192 sec)  -- 	Min: 15.2	Max: 29.9	Mean: 20.8	Mov. Avg: 10.8
# Episode 52 Trial 0
# Episode 52 Trial 100
# Episode 52 Trial 200
# Episode 52 Trial 300
# Episode 52 Trial 400
# Episode 52 Trial 500
# Episode 52 Trial 600
# Episode 52 Trial 700
# Episode 52 Trial 800
# Episode 52 Trial 900
# Episode 52 Trial 1000
# Episode 52 (193 sec)  -- 	Min: 11.4	Max: 30.1	Mean: 22.1	Mov. Avg: 11.0
# Episode 53 Trial 0
# Episode 53 Trial 100
# Episode 53 Trial 200
# Episode 53 Trial 300
# Episode 53 Trial 400
# Episode 53 Trial 500
# Episode 53 Trial 600
# Episode 53 Trial 700
# Episode 53 Trial 800
# Episode 53 Trial 900
# Episode 53 Trial 1000
# Episode 53 (193 sec)  -- 	Min: 13.9	Max: 27.4	Mean: 22.3	Mov. Avg: 11.2
# Episode 54 Trial 0
# Episode 54 Trial 100
# Episode 54 Trial 200
# Episode 54 Trial 300
# Episode 54 Trial 400
# Episode 54 Trial 500
# Episode 54 Trial 600
# Episode 54 Trial 700
# Episode 54 Trial 800
# Episode 54 Trial 900
# Episode 54 Trial 1000
# Episode 54 (192 sec)  -- 	Min: 11.2	Max: 27.2	Mean: 21.8	Mov. Avg: 11.4
# Episode 55 Trial 0
# Episode 55 Trial 100
# Episode 55 Trial 200
# Episode 55 Trial 300
# Episode 55 Trial 400
# Episode 55 Trial 500
# Episode 55 Trial 600
# Episode 55 Trial 700
# Episode 55 Trial 800
# Episode 55 Trial 900
# Episode 55 Trial 1000
# Episode 55 (189 sec)  -- 	Min: 14.1	Max: 30.0	Mean: 22.6	Mov. Avg: 11.6
# Episode 56 Trial 0
# Episode 56 Trial 100
# Episode 56 Trial 200
# Episode 56 Trial 300
# Episode 56 Trial 400
# Episode 56 Trial 500
# Episode 56 Trial 600
# Episode 56 Trial 700
# Episode 56 Trial 800
# Episode 56 Trial 900
# Episode 56 Trial 1000
# Episode 56 (190 sec)  -- 	Min: 19.3	Max: 29.6	Mean: 25.5	Mov. Avg: 11.9
# Episode 57 Trial 0
# Episode 57 Trial 100
# Episode 57 Trial 200
# Episode 57 Trial 300
# Episode 57 Trial 400
# Episode 57 Trial 500
# Episode 57 Trial 600
# Episode 57 Trial 700
# Episode 57 Trial 800
# Episode 57 Trial 900
# Episode 57 Trial 1000
# Episode 57 (190 sec)  -- 	Min: 11.4	Max: 29.8	Mean: 22.5	Mov. Avg: 12.0
# Episode 58 Trial 0
# Episode 58 Trial 100
# Episode 58 Trial 200
# Episode 58 Trial 300
# Episode 58 Trial 400
# Episode 58 Trial 500
# Episode 58 Trial 600
# Episode 58 Trial 700
# Episode 58 Trial 800
# Episode 58 Trial 900
# Episode 58 Trial 1000
# Episode 58 (190 sec)  -- 	Min: 13.6	Max: 32.1	Mean: 23.4	Mov. Avg: 12.2
# Episode 59 Trial 0
# Episode 59 Trial 100
# Episode 59 Trial 200
# Episode 59 Trial 300
# Episode 59 Trial 400
# Episode 59 Trial 500
# Episode 59 Trial 600
# Episode 59 Trial 700
# Episode 59 Trial 800
# Episode 59 Trial 900
# Episode 59 Trial 1000
# Episode 59 (189 sec)  -- 	Min: 16.1	Max: 31.3	Mean: 25.7	Mov. Avg: 12.5
# Episode 60 Trial 0
# Episode 60 Trial 100
# Episode 60 Trial 200
# Episode 60 Trial 300
# Episode 60 Trial 400
# Episode 60 Trial 500
# Episode 60 Trial 600
# Episode 60 Trial 700
# Episode 60 Trial 800
# Episode 60 Trial 900
# Episode 60 Trial 1000
# Episode 60 (188 sec)  -- 	Min: 15.2	Max: 34.3	Mean: 25.5	Mov. Avg: 12.7
# Episode 61 Trial 0
# Episode 61 Trial 100
# Episode 61 Trial 200
# Episode 61 Trial 300
# Episode 61 Trial 400
# Episode 61 Trial 500
# Episode 61 Trial 600
# Episode 61 Trial 700
# Episode 61 Trial 800
# Episode 61 Trial 900
# Episode 61 Trial 1000
# Episode 61 (188 sec)  -- 	Min: 16.7	Max: 36.3	Mean: 26.1	Mov. Avg: 12.9
# Episode 62 Trial 0
# Episode 62 Trial 100
# Episode 62 Trial 200
# Episode 62 Trial 300
# Episode 62 Trial 400
# Episode 62 Trial 500
# Episode 62 Trial 600
# Episode 62 Trial 700
# Episode 62 Trial 800
# Episode 62 Trial 900
# Episode 62 Trial 1000
# Episode 62 (188 sec)  -- 	Min: 13.6	Max: 35.2	Mean: 27.2	Mov. Avg: 13.1
# Episode 63 Trial 0
# Episode 63 Trial 100
# Episode 63 Trial 200
# Episode 63 Trial 300
# Episode 63 Trial 400
# Episode 63 Trial 500
# Episode 63 Trial 600
# Episode 63 Trial 700
# Episode 63 Trial 800
# Episode 63 Trial 900
# Episode 63 Trial 1000
# Episode 63 (189 sec)  -- 	Min: 14.1	Max: 31.0	Mean: 25.7	Mov. Avg: 13.3
# Episode 64 Trial 0
# Episode 64 Trial 100
# Episode 64 Trial 200
# Episode 64 Trial 300
# Episode 64 Trial 400
# Episode 64 Trial 500
# Episode 64 Trial 600
# Episode 64 Trial 700
# Episode 64 Trial 800
# Episode 64 Trial 900
# Episode 64 Trial 1000
# Episode 64 (188 sec)  -- 	Min: 16.6	Max: 35.0	Mean: 25.6	Mov. Avg: 13.5
# Episode 65 Trial 0
# Episode 65 Trial 100
# Episode 65 Trial 200
# Episode 65 Trial 300
# Episode 65 Trial 400
# Episode 65 Trial 500
# Episode 65 Trial 600
# Episode 65 Trial 700
# Episode 65 Trial 800
# Episode 65 Trial 900
# Episode 65 Trial 1000
# Episode 65 (188 sec)  -- 	Min: 20.0	Max: 34.1	Mean: 27.4	Mov. Avg: 13.7
# Episode 66 Trial 0
# Episode 66 Trial 100
# Episode 66 Trial 200
# Episode 66 Trial 300
# Episode 66 Trial 400
# Episode 66 Trial 500
# Episode 66 Trial 600
# Episode 66 Trial 700
# Episode 66 Trial 800
# Episode 66 Trial 900
# Episode 66 Trial 1000
# Episode 66 (189 sec)  -- 	Min: 18.4	Max: 33.6	Mean: 27.6	Mov. Avg: 14.0
# Episode 67 Trial 0
# Episode 67 Trial 100
# Episode 67 Trial 200
# Episode 67 Trial 300
# Episode 67 Trial 400
# Episode 67 Trial 500
# Episode 67 Trial 600
# Episode 67 Trial 700
# Episode 67 Trial 800
# Episode 67 Trial 900
# Episode 67 Trial 1000
# Episode 67 (188 sec)  -- 	Min: 22.3	Max: 33.9	Mean: 29.7	Mov. Avg: 14.2
# Episode 68 Trial 0
# Episode 68 Trial 100
# Episode 68 Trial 200
# Episode 68 Trial 300
# Episode 68 Trial 400
# Episode 68 Trial 500
# Episode 68 Trial 600
# Episode 68 Trial 700
# Episode 68 Trial 800
# Episode 68 Trial 900
# Episode 68 Trial 1000
# Episode 68 (188 sec)  -- 	Min: 16.7	Max: 35.8	Mean: 27.9	Mov. Avg: 14.4
# Episode 69 Trial 0
# Episode 69 Trial 100
# Episode 69 Trial 200
# Episode 69 Trial 300
# Episode 69 Trial 400
# Episode 69 Trial 500
# Episode 69 Trial 600
# Episode 69 Trial 700
# Episode 69 Trial 800
# Episode 69 Trial 900
# Episode 69 Trial 1000
# Episode 69 (188 sec)  -- 	Min: 20.6	Max: 37.2	Mean: 30.6	Mov. Avg: 14.6
# Episode 70 Trial 0
# Episode 70 Trial 100
# Episode 70 Trial 200
# Episode 70 Trial 300
# Episode 70 Trial 400
# Episode 70 Trial 500
# Episode 70 Trial 600
# Episode 70 Trial 700
# Episode 70 Trial 800
# Episode 70 Trial 900
# Episode 70 Trial 1000
# Episode 70 (188 sec)  -- 	Min: 22.8	Max: 33.9	Mean: 29.2	Mov. Avg: 14.8
# Episode 71 Trial 0
# Episode 71 Trial 100
# Episode 71 Trial 200
# Episode 71 Trial 300
# Episode 71 Trial 400
# Episode 71 Trial 500
# Episode 71 Trial 600
# Episode 71 Trial 700
# Episode 71 Trial 800
# Episode 71 Trial 900
# Episode 71 Trial 1000
# Episode 71 (188 sec)  -- 	Min: 27.4	Max: 37.4	Mean: 31.9	Mov. Avg: 15.1
# Episode 72 Trial 0
# Episode 72 Trial 100
# Episode 72 Trial 200
# Episode 72 Trial 300
# Episode 72 Trial 400
# Episode 72 Trial 500
# Episode 72 Trial 600
# Episode 72 Trial 700
# Episode 72 Trial 800
# Episode 72 Trial 900
# Episode 72 Trial 1000
# Episode 72 (187 sec)  -- 	Min: 25.9	Max: 38.2	Mean: 32.4	Mov. Avg: 15.3
# Episode 73 Trial 0
# Episode 73 Trial 100
# Episode 73 Trial 200
# Episode 73 Trial 300
# Episode 73 Trial 400
# Episode 73 Trial 500
# Episode 73 Trial 600
# Episode 73 Trial 700
# Episode 73 Trial 800
# Episode 73 Trial 900
# Episode 73 Trial 1000
# Episode 73 (188 sec)  -- 	Min: 26.1	Max: 38.4	Mean: 32.8	Mov. Avg: 15.6
# Episode 74 Trial 0
# Episode 74 Trial 100
# Episode 74 Trial 200
# Episode 74 Trial 300
# Episode 74 Trial 400
# Episode 74 Trial 500
# Episode 74 Trial 600
# Episode 74 Trial 700
# Episode 74 Trial 800
# Episode 74 Trial 900
# Episode 74 Trial 1000
# Episode 74 (188 sec)  -- 	Min: 24.8	Max: 36.3	Mean: 31.0	Mov. Avg: 15.8
# Episode 75 Trial 0
# Episode 75 Trial 100
# Episode 75 Trial 200
# Episode 75 Trial 300
# Episode 75 Trial 400
# Episode 75 Trial 500
# Episode 75 Trial 600
# Episode 75 Trial 700
# Episode 75 Trial 800
# Episode 75 Trial 900
# Episode 75 Trial 1000
# Episode 75 (188 sec)  -- 	Min: 16.5	Max: 37.9	Mean: 29.5	Mov. Avg: 15.9
# Episode 76 Trial 0
# Episode 76 Trial 100
# Episode 76 Trial 200
# Episode 76 Trial 300
# Episode 76 Trial 400
# Episode 76 Trial 500
# Episode 76 Trial 600
# Episode 76 Trial 700
# Episode 76 Trial 800
# Episode 76 Trial 900
# Episode 76 Trial 1000
# Episode 76 (188 sec)  -- 	Min: 25.6	Max: 38.0	Mean: 31.4	Mov. Avg: 16.1
# Episode 77 Trial 0
# Episode 77 Trial 100
# Episode 77 Trial 200
# Episode 77 Trial 300
# Episode 77 Trial 400
# Episode 77 Trial 500
# Episode 77 Trial 600
# Episode 77 Trial 700
# Episode 77 Trial 800
# Episode 77 Trial 900
# Episode 77 Trial 1000
# Episode 77 (187 sec)  -- 	Min: 21.0	Max: 39.5	Mean: 31.5	Mov. Avg: 16.3
# Episode 78 Trial 0
# Episode 78 Trial 100
# Episode 78 Trial 200
# Episode 78 Trial 300
# Episode 78 Trial 400
# Episode 78 Trial 500
# Episode 78 Trial 600
# Episode 78 Trial 700
# Episode 78 Trial 800
# Episode 78 Trial 900
# Episode 78 Trial 1000
# Episode 78 (186 sec)  -- 	Min: 18.7	Max: 37.7	Mean: 30.3	Mov. Avg: 16.5
# Episode 79 Trial 0
# Episode 79 Trial 100
# Episode 79 Trial 200
# Episode 79 Trial 300
# Episode 79 Trial 400
# Episode 79 Trial 500
# Episode 79 Trial 600
# Episode 79 Trial 700
# Episode 79 Trial 800
# Episode 79 Trial 900
# Episode 79 Trial 1000
# Episode 79 (186 sec)  -- 	Min: 22.4	Max: 36.4	Mean: 30.6	Mov. Avg: 16.7
# Episode 80 Trial 0
# Episode 80 Trial 100
# Episode 80 Trial 200
# Episode 80 Trial 300
# Episode 80 Trial 400
# Episode 80 Trial 500
# Episode 80 Trial 600
# Episode 80 Trial 700
# Episode 80 Trial 800
# Episode 80 Trial 900
# Episode 80 Trial 1000
# Episode 80 (187 sec)  -- 	Min: 25.8	Max: 39.3	Mean: 32.2	Mov. Avg: 16.9
# Episode 81 Trial 0
# Episode 81 Trial 100
# Episode 81 Trial 200
# Episode 81 Trial 300
# Episode 81 Trial 400
# Episode 81 Trial 500
# Episode 81 Trial 600
# Episode 81 Trial 700
# Episode 81 Trial 800
# Episode 81 Trial 900
# Episode 81 Trial 1000
# Episode 81 (188 sec)  -- 	Min: 24.1	Max: 37.9	Mean: 33.5	Mov. Avg: 17.1
# Episode 82 Trial 0
# Episode 82 Trial 100
# Episode 82 Trial 200
# Episode 82 Trial 300
# Episode 82 Trial 400
# Episode 82 Trial 500
# Episode 82 Trial 600
# Episode 82 Trial 700
# Episode 82 Trial 800
# Episode 82 Trial 900
# Episode 82 Trial 1000
# Episode 82 (188 sec)  -- 	Min: 20.0	Max: 37.1	Mean: 32.2	Mov. Avg: 17.3
# Episode 83 Trial 0
# Episode 83 Trial 100
# Episode 83 Trial 200
# Episode 83 Trial 300
# Episode 83 Trial 400
# Episode 83 Trial 500
# Episode 83 Trial 600
# Episode 83 Trial 700
# Episode 83 Trial 800
# Episode 83 Trial 900
# Episode 83 Trial 1000
# Episode 83 (188 sec)  -- 	Min: 20.7	Max: 38.1	Mean: 31.4	Mov. Avg: 17.5
# Episode 84 Trial 0
# Episode 84 Trial 100
# Episode 84 Trial 200
# Episode 84 Trial 300
# Episode 84 Trial 400
# Episode 84 Trial 500
# Episode 84 Trial 600
# Episode 84 Trial 700
# Episode 84 Trial 800
# Episode 84 Trial 900
# Episode 84 Trial 1000
# Episode 84 (189 sec)  -- 	Min: 22.5	Max: 38.8	Mean: 32.4	Mov. Avg: 17.6
# Episode 85 Trial 0
# Episode 85 Trial 100
# Episode 85 Trial 200
# Episode 85 Trial 300
# Episode 85 Trial 400
# Episode 85 Trial 500
# Episode 85 Trial 600
# Episode 85 Trial 700
# Episode 85 Trial 800
# Episode 85 Trial 900
# Episode 85 Trial 1000
# Episode 85 (188 sec)  -- 	Min: 19.5	Max: 39.3	Mean: 31.3	Mov. Avg: 17.8
# Episode 86 Trial 0
# Episode 86 Trial 100
# Episode 86 Trial 200
# Episode 86 Trial 300
# Episode 86 Trial 400
# Episode 86 Trial 500
# Episode 86 Trial 600
# Episode 86 Trial 700
# Episode 86 Trial 800
# Episode 86 Trial 900
# Episode 86 Trial 1000
# Episode 86 (189 sec)  -- 	Min: 22.9	Max: 39.5	Mean: 31.7	Mov. Avg: 18.0
# Episode 87 Trial 0
# Episode 87 Trial 100
# Episode 87 Trial 200
# Episode 87 Trial 300
# Episode 87 Trial 400
# Episode 87 Trial 500
# Episode 87 Trial 600
# Episode 87 Trial 700
# Episode 87 Trial 800
# Episode 87 Trial 900
# Episode 87 Trial 1000
# Episode 87 (188 sec)  -- 	Min: 20.8	Max: 37.3	Mean: 32.8	Mov. Avg: 18.1
# Episode 88 Trial 0
# Episode 88 Trial 100
# Episode 88 Trial 200
# Episode 88 Trial 300
# Episode 88 Trial 400
# Episode 88 Trial 500
# Episode 88 Trial 600
# Episode 88 Trial 700
# Episode 88 Trial 800
# Episode 88 Trial 900
# Episode 88 Trial 1000
# Episode 88 (189 sec)  -- 	Min: 21.2	Max: 36.4	Mean: 30.7	Mov. Avg: 18.3
# Episode 89 Trial 0
# Episode 89 Trial 100
# Episode 89 Trial 200
# Episode 89 Trial 300
# Episode 89 Trial 400
# Episode 89 Trial 500
# Episode 89 Trial 600
# Episode 89 Trial 700
# Episode 89 Trial 800
# Episode 89 Trial 900
# Episode 89 Trial 1000
# Episode 89 (189 sec)  -- 	Min: 20.9	Max: 37.1	Mean: 30.7	Mov. Avg: 18.4
# Episode 90 Trial 0
# Episode 90 Trial 100
# Episode 90 Trial 200
# Episode 90 Trial 300
# Episode 90 Trial 400
# Episode 90 Trial 500
# Episode 90 Trial 600
# Episode 90 Trial 700
# Episode 90 Trial 800
# Episode 90 Trial 900
# Episode 90 Trial 1000
# Episode 90 (189 sec)  -- 	Min: 23.4	Max: 37.1	Mean: 32.5	Mov. Avg: 18.6
# Episode 91 Trial 0
# Episode 91 Trial 100
# Episode 91 Trial 200
# Episode 91 Trial 300
# Episode 91 Trial 400
# Episode 91 Trial 500
# Episode 91 Trial 600
# Episode 91 Trial 700
# Episode 91 Trial 800
# Episode 91 Trial 900
# Episode 91 Trial 1000
# Episode 91 (189 sec)  -- 	Min: 27.7	Max: 38.7	Mean: 33.7	Mov. Avg: 18.7
# Episode 92 Trial 0
# Episode 92 Trial 100
# Episode 92 Trial 200
# Episode 92 Trial 300
# Episode 92 Trial 400
# Episode 92 Trial 500
# Episode 92 Trial 600
# Episode 92 Trial 700
# Episode 92 Trial 800
# Episode 92 Trial 900
# Episode 92 Trial 1000
# Episode 92 (189 sec)  -- 	Min: 17.2	Max: 39.1	Mean: 32.7	Mov. Avg: 18.9
# Episode 93 Trial 0
# Episode 93 Trial 100
# Episode 93 Trial 200
# Episode 93 Trial 300
# Episode 93 Trial 400
# Episode 93 Trial 500
# Episode 93 Trial 600
# Episode 93 Trial 700
# Episode 93 Trial 800
# Episode 93 Trial 900
# Episode 93 Trial 1000
# Episode 93 (189 sec)  -- 	Min: 23.4	Max: 39.4	Mean: 34.0	Mov. Avg: 19.0
# Episode 94 Trial 0
# Episode 94 Trial 100
# Episode 94 Trial 200
# Episode 94 Trial 300
# Episode 94 Trial 400
# Episode 94 Trial 500
# Episode 94 Trial 600
# Episode 94 Trial 700
# Episode 94 Trial 800
# Episode 94 Trial 900
# Episode 94 Trial 1000
# Episode 94 (189 sec)  -- 	Min: 27.1	Max: 38.5	Mean: 33.4	Mov. Avg: 19.2
# Episode 95 Trial 0
# Episode 95 Trial 100
# Episode 95 Trial 200
# Episode 95 Trial 300
# Episode 95 Trial 400
# Episode 95 Trial 500
# Episode 95 Trial 600
# Episode 95 Trial 700
# Episode 95 Trial 800
# Episode 95 Trial 900
# Episode 95 Trial 1000
# Episode 95 (189 sec)  -- 	Min: 27.7	Max: 39.5	Mean: 35.1	Mov. Avg: 19.4
# Episode 96 Trial 0
# Episode 96 Trial 100
# Episode 96 Trial 200
# Episode 96 Trial 300
# Episode 96 Trial 400
# Episode 96 Trial 500
# Episode 96 Trial 600
# Episode 96 Trial 700
# Episode 96 Trial 800
# Episode 96 Trial 900
# Episode 96 Trial 1000
# Episode 96 (189 sec)  -- 	Min: 29.8	Max: 38.9	Mean: 35.6	Mov. Avg: 19.5
# Episode 97 Trial 0
# Episode 97 Trial 100
# Episode 97 Trial 200
# Episode 97 Trial 300
# Episode 97 Trial 400
# Episode 97 Trial 500
# Episode 97 Trial 600
# Episode 97 Trial 700
# Episode 97 Trial 800
# Episode 97 Trial 900
# Episode 97 Trial 1000
# Episode 97 (188 sec)  -- 	Min: 21.4	Max: 37.3	Mean: 31.8	Mov. Avg: 19.7
# Episode 98 Trial 0
# Episode 98 Trial 100
# Episode 98 Trial 200
# Episode 98 Trial 300
# Episode 98 Trial 400
# Episode 98 Trial 500
# Episode 98 Trial 600
# Episode 98 Trial 700
# Episode 98 Trial 800
# Episode 98 Trial 900
# Episode 98 Trial 1000
# Episode 98 (189 sec)  -- 	Min: 26.5	Max: 37.7	Mean: 32.6	Mov. Avg: 19.8
# Episode 99 Trial 0
# Episode 99 Trial 100
# Episode 99 Trial 200
# Episode 99 Trial 300
# Episode 99 Trial 400
# Episode 99 Trial 500
# Episode 99 Trial 600
# Episode 99 Trial 700
# Episode 99 Trial 800
# Episode 99 Trial 900
# Episode 99 Trial 1000
# Episode 99 (189 sec)  -- 	Min: 23.7	Max: 37.1	Mean: 33.2	Mov. Avg: 19.9
# Episode 100 Trial 0
# Episode 100 Trial 100
# Episode 100 Trial 200
# Episode 100 Trial 300
# Episode 100 Trial 400
# Episode 100 Trial 500
# Episode 100 Trial 600
# Episode 100 Trial 700
# Episode 100 Trial 800
# Episode 100 Trial 900
# Episode 100 Trial 1000
# Episode 100 (189 sec)  -- 	Min: 22.6	Max: 38.7	Mean: 33.2	Mov. Avg: 20.1
# Episode 101 Trial 0
# Episode 101 Trial 100
# Episode 101 Trial 200
# Episode 101 Trial 300
# Episode 101 Trial 400
# Episode 101 Trial 500
# Episode 101 Trial 600
# Episode 101 Trial 700
# Episode 101 Trial 800
# Episode 101 Trial 900
# Episode 101 Trial 1000
# Episode 101 (188 sec)  -- 	Min: 25.8	Max: 36.6	Mean: 33.4	Mov. Avg: 20.4
# Episode 102 Trial 0
# Episode 102 Trial 100
# Episode 102 Trial 200
# Episode 102 Trial 300
# Episode 102 Trial 400
# Episode 102 Trial 500
# Episode 102 Trial 600
# Episode 102 Trial 700
# Episode 102 Trial 800
# Episode 102 Trial 900
# Episode 102 Trial 1000
# Episode 102 (188 sec)  -- 	Min: 27.7	Max: 39.2	Mean: 34.1	Mov. Avg: 20.7
# Episode 103 Trial 0
# Episode 103 Trial 100
# Episode 103 Trial 200
# Episode 103 Trial 300
# Episode 103 Trial 400
# Episode 103 Trial 500
# Episode 103 Trial 600
# Episode 103 Trial 700
# Episode 103 Trial 800
# Episode 103 Trial 900
# Episode 103 Trial 1000
# Episode 103 (189 sec)  -- 	Min: 18.7	Max: 38.8	Mean: 34.0	Mov. Avg: 21.0
# Episode 104 Trial 0
# Episode 104 Trial 100
# Episode 104 Trial 200
# Episode 104 Trial 300
# Episode 104 Trial 400
# Episode 104 Trial 500
# Episode 104 Trial 600
# Episode 104 Trial 700
# Episode 104 Trial 800
# Episode 104 Trial 900
# Episode 104 Trial 1000
# Episode 104 (188 sec)  -- 	Min: 28.9	Max: 38.7	Mean: 34.6	Mov. Avg: 21.4
# Episode 105 Trial 0
# Episode 105 Trial 100
# Episode 105 Trial 200
# Episode 105 Trial 300
# Episode 105 Trial 400
# Episode 105 Trial 500
# Episode 105 Trial 600
# Episode 105 Trial 700
# Episode 105 Trial 800
# Episode 105 Trial 900
# Episode 105 Trial 1000
# Episode 105 (189 sec)  -- 	Min: 26.1	Max: 38.1	Mean: 33.6	Mov. Avg: 21.7
# Episode 106 Trial 0
# Episode 106 Trial 100
# Episode 106 Trial 200
# Episode 106 Trial 300
# Episode 106 Trial 400
# Episode 106 Trial 500
# Episode 106 Trial 600
# Episode 106 Trial 700
# Episode 106 Trial 800
# Episode 106 Trial 900
# Episode 106 Trial 1000
# Episode 106 (189 sec)  -- 	Min: 27.5	Max: 38.5	Mean: 33.5	Mov. Avg: 22.0
# Episode 107 Trial 0
# Episode 107 Trial 100
# Episode 107 Trial 200
# Episode 107 Trial 300
# Episode 107 Trial 400
# Episode 107 Trial 500
# Episode 107 Trial 600
# Episode 107 Trial 700
# Episode 107 Trial 800
# Episode 107 Trial 900
# Episode 107 Trial 1000
# Episode 107 (188 sec)  -- 	Min: 27.2	Max: 38.4	Mean: 33.7	Mov. Avg: 22.3
# Episode 108 Trial 0
# Episode 108 Trial 100
# Episode 108 Trial 200
# Episode 108 Trial 300
# Episode 108 Trial 400
# Episode 108 Trial 500
# Episode 108 Trial 600
# Episode 108 Trial 700
# Episode 108 Trial 800
# Episode 108 Trial 900
# Episode 108 Trial 1000
# Episode 108 (189 sec)  -- 	Min: 25.6	Max: 38.9	Mean: 33.1	Mov. Avg: 22.6
# Episode 109 Trial 0
# Episode 109 Trial 100
# Episode 109 Trial 200
# Episode 109 Trial 300
# Episode 109 Trial 400
# Episode 109 Trial 500
# Episode 109 Trial 600
# Episode 109 Trial 700
# Episode 109 Trial 800
# Episode 109 Trial 900
# Episode 109 Trial 1000
# Episode 109 (189 sec)  -- 	Min: 28.9	Max: 38.2	Mean: 34.5	Mov. Avg: 22.9
# Episode 110 Trial 0
# Episode 110 Trial 100
# Episode 110 Trial 200
# Episode 110 Trial 300
# Episode 110 Trial 400
# Episode 110 Trial 500
# Episode 110 Trial 600
# Episode 110 Trial 700
# Episode 110 Trial 800
# Episode 110 Trial 900
# Episode 110 Trial 1000
# Episode 110 (189 sec)  -- 	Min: 28.0	Max: 37.9	Mean: 34.0	Mov. Avg: 23.2
# Episode 111 Trial 0
# Episode 111 Trial 100
# Episode 111 Trial 200
# Episode 111 Trial 300
# Episode 111 Trial 400
# Episode 111 Trial 500
# Episode 111 Trial 600
# Episode 111 Trial 700
# Episode 111 Trial 800
# Episode 111 Trial 900
# Episode 111 Trial 1000
# Episode 111 (189 sec)  -- 	Min: 26.4	Max: 37.6	Mean: 33.6	Mov. Avg: 23.5
# Episode 112 Trial 0
# Episode 112 Trial 100
# Episode 112 Trial 200
# Episode 112 Trial 300
# Episode 112 Trial 400
# Episode 112 Trial 500
# Episode 112 Trial 600
# Episode 112 Trial 700
# Episode 112 Trial 800
# Episode 112 Trial 900
# Episode 112 Trial 1000
# Episode 112 (189 sec)  -- 	Min: 27.3	Max: 38.9	Mean: 34.2	Mov. Avg: 23.8
# Episode 113 Trial 0
# Episode 113 Trial 100
# Episode 113 Trial 200
# Episode 113 Trial 300
# Episode 113 Trial 400
# Episode 113 Trial 500
# Episode 113 Trial 600
# Episode 113 Trial 700
# Episode 113 Trial 800
# Episode 113 Trial 900
# Episode 113 Trial 1000
# Episode 113 (188 sec)  -- 	Min: 31.7	Max: 39.3	Mean: 35.6	Mov. Avg: 24.1
# Episode 114 Trial 0
# Episode 114 Trial 100
# Episode 114 Trial 200
# Episode 114 Trial 300
# Episode 114 Trial 400
# Episode 114 Trial 500
# Episode 114 Trial 600
# Episode 114 Trial 700
# Episode 114 Trial 800
# Episode 114 Trial 900
# Episode 114 Trial 1000
# Episode 114 (187 sec)  -- 	Min: 26.0	Max: 38.5	Mean: 35.1	Mov. Avg: 24.4
# Episode 115 Trial 0
# Episode 115 Trial 100
# Episode 115 Trial 200
# Episode 115 Trial 300
# Episode 115 Trial 400
# Episode 115 Trial 500
# Episode 115 Trial 600
# Episode 115 Trial 700
# Episode 115 Trial 800
# Episode 115 Trial 900
# Episode 115 Trial 1000
# Episode 115 (188 sec)  -- 	Min: 24.3	Max: 38.3	Mean: 34.5	Mov. Avg: 24.7
# Episode 116 Trial 0
# Episode 116 Trial 100
# Episode 116 Trial 200
# Episode 116 Trial 300
# Episode 116 Trial 400
# Episode 116 Trial 500
# Episode 116 Trial 600
# Episode 116 Trial 700
# Episode 116 Trial 800
# Episode 116 Trial 900
# Episode 116 Trial 1000
# Episode 116 (189 sec)  -- 	Min: 29.2	Max: 38.3	Mean: 35.4	Mov. Avg: 25.0
# Episode 117 Trial 0
# Episode 117 Trial 100
# Episode 117 Trial 200
# Episode 117 Trial 300
# Episode 117 Trial 400
# Episode 117 Trial 500
# Episode 117 Trial 600
# Episode 117 Trial 700
# Episode 117 Trial 800
# Episode 117 Trial 900
# Episode 117 Trial 1000
# Episode 117 (189 sec)  -- 	Min: 24.7	Max: 39.2	Mean: 35.1	Mov. Avg: 25.3
# Episode 118 Trial 0
# Episode 118 Trial 100
# Episode 118 Trial 200
# Episode 118 Trial 300
# Episode 118 Trial 400
# Episode 118 Trial 500
# Episode 118 Trial 600
# Episode 118 Trial 700
# Episode 118 Trial 800
# Episode 118 Trial 900
# Episode 118 Trial 1000
# Episode 118 (189 sec)  -- 	Min: 30.6	Max: 38.0	Mean: 34.7	Mov. Avg: 25.5
# Episode 119 Trial 0
# Episode 119 Trial 100
# Episode 119 Trial 200
# Episode 119 Trial 300
# Episode 119 Trial 400
# Episode 119 Trial 500
# Episode 119 Trial 600
# Episode 119 Trial 700
# Episode 119 Trial 800
# Episode 119 Trial 900
# Episode 119 Trial 1000
# Episode 119 (189 sec)  -- 	Min: 24.7	Max: 39.2	Mean: 33.6	Mov. Avg: 25.8
# Episode 120 Trial 0
# Episode 120 Trial 100
# Episode 120 Trial 200
# Episode 120 Trial 300
# Episode 120 Trial 400
# Episode 120 Trial 500
# Episode 120 Trial 600
# Episode 120 Trial 700
# Episode 120 Trial 800
# Episode 120 Trial 900
# Episode 120 Trial 1000
# Episode 120 (188 sec)  -- 	Min: 29.0	Max: 38.1	Mean: 35.2	Mov. Avg: 26.1
# Episode 121 Trial 0
# Episode 121 Trial 100
# Episode 121 Trial 200
# Episode 121 Trial 300
# Episode 121 Trial 400
# Episode 121 Trial 500
# Episode 121 Trial 700
# Episode 121 Trial 800
# Episode 121 Trial 900
# Episode 121 Trial 1000
# Episode 121 (189 sec)  -- 	Min: 25.4	Max: 38.7	Mean: 32.5	Mov. Avg: 26.3
# Episode 122 Trial 0
# Episode 122 Trial 100
# Episode 122 Trial 200
# Episode 122 Trial 300
# Episode 122 Trial 400
# Episode 122 Trial 500
# Episode 122 Trial 600
# Episode 122 Trial 700
# Episode 122 Trial 800
# Episode 122 Trial 900
# Episode 122 Trial 1000
# Episode 122 (189 sec)  -- 	Min: 24.1	Max: 39.0	Mean: 33.9	Mov. Avg: 26.6
# Episode 123 Trial 0
# Episode 123 Trial 100
# Episode 123 Trial 200
# Episode 123 Trial 300
# Episode 123 Trial 400
# Episode 123 Trial 500
# Episode 123 Trial 600
# Episode 123 Trial 700
# Episode 123 Trial 800
# Episode 123 Trial 900
# Episode 123 Trial 1000
# Episode 123 (189 sec)  -- 	Min: 32.3	Max: 39.3	Mean: 36.8	Mov. Avg: 26.9
# Episode 124 Trial 0
# Episode 124 Trial 100
# Episode 124 Trial 200
# Episode 124 Trial 300
# Episode 124 Trial 400
# Episode 124 Trial 500
# Episode 124 Trial 600
# Episode 124 Trial 700
# Episode 124 Trial 800
# Episode 124 Trial 900
# Episode 124 Trial 1000
# Episode 124 (189 sec)  -- 	Min: 28.8	Max: 38.6	Mean: 35.6	Mov. Avg: 27.1
# Episode 125 Trial 0
# Episode 125 Trial 100
# Episode 125 Trial 200
# Episode 125 Trial 300
# Episode 125 Trial 400
# Episode 125 Trial 500
# Episode 125 Trial 600
# Episode 125 Trial 700
# Episode 125 Trial 800
# Episode 125 Trial 900
# Episode 125 Trial 1000
# Episode 125 (188 sec)  -- 	Min: 31.7	Max: 38.9	Mean: 35.9	Mov. Avg: 27.4
# Episode 126 Trial 0
# Episode 126 Trial 100
# Episode 126 Trial 200
# Episode 126 Trial 300
# Episode 126 Trial 400
# Episode 126 Trial 500
# Episode 126 Trial 600
# Episode 126 Trial 700
# Episode 126 Trial 800
# Episode 126 Trial 900
# Episode 126 Trial 1000
# Episode 126 (188 sec)  -- 	Min: 29.4	Max: 39.3	Mean: 35.6	Mov. Avg: 27.6
# Episode 127 Trial 0
# Episode 127 Trial 100
# Episode 127 Trial 200
# Episode 127 Trial 300
# Episode 127 Trial 400
# Episode 127 Trial 500
# Episode 127 Trial 600
# Episode 127 Trial 700
# Episode 127 Trial 800
# Episode 127 Trial 900
# Episode 127 Trial 1000
# Episode 127 (188 sec)  -- 	Min: 33.0	Max: 39.4	Mean: 36.3	Mov. Avg: 27.9
# Episode 128 Trial 0
# Episode 128 Trial 100
# Episode 128 Trial 200
# Episode 128 Trial 300
# Episode 128 Trial 400
# Episode 128 Trial 500
# Episode 128 Trial 600
# Episode 128 Trial 700
# Episode 128 Trial 800
# Episode 128 Trial 900
# Episode 128 Trial 1000
# Episode 128 (188 sec)  -- 	Min: 32.6	Max: 38.6	Mean: 35.5	Mov. Avg: 28.1
# Episode 129 Trial 0
# Episode 129 Trial 100
# Episode 129 Trial 200
# Episode 129 Trial 300
# Episode 129 Trial 400
# Episode 129 Trial 500
# Episode 129 Trial 600
# Episode 129 Trial 700
# Episode 129 Trial 800
# Episode 129 Trial 900
# Episode 129 Trial 1000
# Episode 129 (189 sec)  -- 	Min: 32.8	Max: 39.2	Mean: 36.2	Mov. Avg: 28.3
# Episode 130 Trial 0
# Episode 130 Trial 100
# Episode 130 Trial 200
# Episode 130 Trial 300
# Episode 130 Trial 400
# Episode 130 Trial 500
# Episode 130 Trial 600
# Episode 130 Trial 700
# Episode 130 Trial 800
# Episode 130 Trial 900
# Episode 130 Trial 1000
# Episode 130 (188 sec)  -- 	Min: 30.2	Max: 39.0	Mean: 35.8	Mov. Avg: 28.6
# Episode 131 Trial 0
# Episode 131 Trial 100
# Episode 131 Trial 200
# Episode 131 Trial 300
# Episode 131 Trial 400
# Episode 131 Trial 500
# Episode 131 Trial 600
# Episode 131 Trial 700
# Episode 131 Trial 800
# Episode 131 Trial 900
# Episode 131 Trial 1000
# Episode 131 (188 sec)  -- 	Min: 25.9	Max: 38.8	Mean: 36.0	Mov. Avg: 28.8
# Episode 132 Trial 0
# Episode 132 Trial 100
# Episode 132 Trial 200
# Episode 132 Trial 300
# Episode 132 Trial 400
# Episode 132 Trial 500
# Episode 132 Trial 600
# Episode 132 Trial 700
# Episode 132 Trial 800
# Episode 132 Trial 900
# Episode 132 Trial 1000
# Episode 132 (188 sec)  -- 	Min: 31.5	Max: 39.2	Mean: 35.0	Mov. Avg: 29.0
# Episode 133 Trial 0
# Episode 133 Trial 100
# Episode 133 Trial 200
# Episode 133 Trial 300
# Episode 133 Trial 400
# Episode 133 Trial 500
# Episode 133 Trial 600
# Episode 133 Trial 700
# Episode 133 Trial 800
# Episode 133 Trial 900
# Episode 133 Trial 1000
# Episode 133 (188 sec)  -- 	Min: 20.2	Max: 39.6	Mean: 35.2	Mov. Avg: 29.2
# Episode 134 Trial 0
# Episode 134 Trial 100
# Episode 134 Trial 200
# Episode 134 Trial 300
# Episode 134 Trial 400
# Episode 134 Trial 500
# Episode 134 Trial 600
# Episode 134 Trial 700
# Episode 134 Trial 800
# Episode 134 Trial 900
# Episode 134 Trial 1000
# Episode 134 (188 sec)  -- 	Min: 26.0	Max: 39.4	Mean: 35.4	Mov. Avg: 29.4
# Episode 135 Trial 0
# Episode 135 Trial 100
# Episode 135 Trial 200
# Episode 135 Trial 300
# Episode 135 Trial 400
# Episode 135 Trial 500
# Episode 135 Trial 600
# Episode 135 Trial 700
# Episode 135 Trial 800
# Episode 135 Trial 900
# Episode 135 Trial 1000
# Episode 135 (188 sec)  -- 	Min: 24.9	Max: 38.3	Mean: 34.8	Mov. Avg: 29.6
# Episode 136 Trial 0
# Episode 136 Trial 100
# Episode 136 Trial 200
# Episode 136 Trial 300
# Episode 136 Trial 400
# Episode 136 Trial 500
# Episode 136 Trial 600
# Episode 136 Trial 700
# Episode 136 Trial 800
# Episode 136 Trial 900
# Episode 136 Trial 1000
# Episode 136 (188 sec)  -- 	Min: 24.0	Max: 39.5	Mean: 34.5	Mov. Avg: 29.8
# Episode 137 Trial 0
# Episode 137 Trial 100
# Episode 137 Trial 200
# Episode 137 Trial 300
# Episode 137 Trial 400
# Episode 137 Trial 500
# Episode 137 Trial 600
# Episode 137 Trial 700
# Episode 137 Trial 800
# Episode 137 Trial 900
# Episode 137 Trial 1000
# Episode 137 (188 sec)  -- 	Min: 30.2	Max: 38.4	Mean: 35.1	Mov. Avg: 29.9
# Episode 138 Trial 0
# Episode 138 Trial 100
# Episode 138 Trial 200
# Episode 138 Trial 300
# Episode 138 Trial 400
# Episode 138 Trial 500
# Episode 138 Trial 600
# Episode 138 Trial 700
# Episode 138 Trial 800
# Episode 138 Trial 900
# Episode 138 Trial 1000
# Episode 138 (189 sec)  -- 	Min: 31.5	Max: 38.8	Mean: 36.4	Mov. Avg: 30.2
#
# Environment SOLVED in 38 episodes!	Moving Average =30.2 over last 100 episodes

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# plot scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDPG')
plt.plot(np.arange(len(scores)), avgs, c='r', label='moving avg')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
